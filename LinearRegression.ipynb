# %% [markdown]
# <a href="https://colab.research.google.com/github/yaminiparmesh/LINEAR-REGRESSION/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# !ls /content/sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
df=pd.read_csv('/content/sample_data/california_housing_train.csv')
print(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.plot(x,y)
plt.show()

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn

# %% [markdown]
# DAIABRTES DITECTION

# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,class_likelihood_ratios

# %%
url="/content/diabetes.csv"

columns=[
    "id","chol","stab.glu","hdl","ratio","glyhb","location","age","gender","height","weight","frame","bp.1s","bp.1d","bp.2s","bp.2d","waist","hip","time.ppn"
]
df=pd.read_csv(url,names=columns)

# %%
print("first 5 row of dataset:")
print(df.head())

print("\ndataset information:")
print(df.info())

print("\ndataset description:")
print(df.describe())
# Out:
# first 5 row of dataset:
#      id  chol  stab.glu  hdl         ratio         glyhb    location  age  \
# 0    id  chol  stab.glu  hdl         ratio         glyhb    location  age
# 1  1000   203        82   56  3.5999999046  4.3099999428  Buckingham   46
# 2  1001   165        97   24  6.9000000954  4.4400000572  Buckingham   29
# 3  1002   228        92   37  6.1999998093  4.6399998665  Buckingham   58
# 4  1003    78        93   12           6.5  4.6300001144  Buckingham   67
#
#    gender  height  weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist  hip  \
# 0  gender  height  weight   frame  bp.1s  bp.1d  bp.2s  bp.2d  waist  hip
# 1  female      62     121  medium    118     59    NaN    NaN     29   38
# 2  female      64     218   large    112     68    NaN    NaN     46   48
# 3  female      61     256   large    190     92    185     92     49   57
# 4    male      67     119   large    110     50    NaN    NaN     33   38
#
#    time.ppn
# 0  time.ppn
# 1       720
# ...

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="time.ppn",data=df)
plt.title("Distribution of time.ppn")
plt.show()

# %%
x=df.drop("time.ppn",axis=1) # Updated target column
y=df["time.ppn"] # Updated target column

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
accuracy=accuracy_score(y_test,prediction) # Fixed typo: predication to prediction
print("\nmodel accuracy:",accuracy)

print("\nconfusion matrix:")
print(confusion_matrix(y_test,prediction)) # Fixed arguments for confusion_matrix

print("\nclassification report:")
print(classification_report(y_test,prediction)) # Fixed arguments for classification_report
# Out:
# model accuracy: 0.9012345679012346
#
# confusion matrix:
# [[65  1]
#  [ 7  8]]
#
# classification report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94        66
#            1       0.89      0.53      0.67        15
#
#     accuracy                           0.90        81
#    macro avg       0.90      0.76      0.80        81
# weighted avg       0.90      0.90      0.89        81

# %% [markdown]
# **HOME RESNTALPREDEDICTION**

# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv('/content/home-rental.csv')

x=df[['size']]
y=df[['rent_amount']]

# %%
from numpy.random.mtrand import random
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
mse=mean_squared_error(y_test,y_pred)
print("mean squared error:",mse)
# Out:
# mean squared error: 3781.01129644514

# %%
plt.scatter(x,y,color="blue")
plt.plot(x,model.predict(x),color='red')
plt.xlabel('size')
plt.ylabel('rent_amount($1000)')
plt.title('home rental analysis')
plt.show()

# %% [markdown]
# MALL CUSTEMER SEGMENTATION

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering

# %%
import pandas as pd
df=pd.read_csv('/content/Mall_Customers.csv')

# %%
x=df[['Annual Income (k$)','Spending Score (1-100)']]

# %%
agg_model=AgglomerativeClustering(n_clusters=3)

# %%
df['cluster']=agg_model.fit_predict(x)

# %%
plt.scatter(x['Annual Income (k$)'],x['Spending Score (1-100)'],c=df['cluster'],cmap='rainbow')
plt.xlabel('annual income')
plt.ylabel('spending score')
plt.title('Aggleomerative clustering example')
plt.show()

# %% [markdown]
# Home rental anlysis(Kmeans)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df=pd.read_csv('/content/home-rental.csv')

# %%
kmeans=KMeans(n_clusters=3,random_state=42)
X = df[['size', 'bedrooms', 'rent_amount']]
df['cluster']=kmeans.fit_predict(X)

# %%
controids=kmeans.cluster_centers_

# %%
plt.scatter(df['size'], df['rent_amount'], c=df['cluster'], cmap='rainbow')
plt.scatter(controids[:,0], controids[:,2], color='black', marker='x', s=100)
plt.xlabel('size')
plt.ylabel('rent_amount')
plt.title("home rental analysis")
plt.show()

# %% [markdown]
# **Image face detection**

# %%
# !pip install opencv-python matplotlib --quiet

# %%
import cv2
from matplotlib import pyplot as pyplot
from google.colab import files

# %%
import os

# Define a path for a known good sample image
working_image_path = '/content/sample_face.jpg'

# Unconditionally download a sample image to ensure we have a valid one
print(f"Downloading a sample image to '{working_image_path}'.")
# !wget -O '{working_image_path}' 'https://upload.wikimedia.org/wikipedia/commons/8/8d/President_Barack_Obama.jpg'

# Update image_file to point to the downloaded image
image_file = working_image_path

image=cv2.imread(image_file)

if image is None:
    print(f"Error: Could not load image from '{image_file}'. Please check the file path and ensure it's a valid image or upload one.")
else:
    print(f"Successfully loaded image from '{image_file}'.")
# Out:
# ...
# --2026-03-16 04:14:14--  https://upload.wikimedia.org/wikipedia/commons/8/8d/President_Barack_Obama.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1276121 (1.2M) [image/jpeg]
# Saving to: ‘/content/sample_face.jpg’
#
# /content/sample_fac 100%[===================>]   1.22M  --.-KB/s    in 0.1s
#
# 2026-03-16 04:14:15 (9.76 MB/s) - ‘/content/sample_face.jpg’ saved [1276121/1276121]
#
# Successfully loaded image from '/content/sample_face.jpg'.

# %%
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
faces=face_cascade.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=5)

# %%
for(x,y,w,h)in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),2)

# %%
import matplotlib.pyplot as plt

# Convert the BGR image (with drawn rectangles) to RGB for matplotlib display
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(8,6))
plt.imshow(image_rgb)
plt.title("detected face")
plt.axis('off')
plt.show()
